# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from dateutil import parser
import sys
import warnings
from scipy import stats
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from sklearn.utils import resample
from sklearn import tree
from sklearn import svm
from sklearn.model_selection import KFold
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
covid = pd.read_csv("C:/Users/MartinV/Downloads/Covid Continent.csv")
euribor = pd.read_excel("C:/Users/MartinV/Downloads/Euribor.xlsx")
covid
# Out:
#       iso_code      continent       location       date  total_cases  \
# 0          ABW  North America          Aruba  3/13/2020          2.0
# 1          ABW  North America          Aruba  3/20/2020          4.0
# 2          ABW  North America          Aruba  3/24/2020         12.0
# 3          ABW  North America          Aruba  3/25/2020         17.0
# 4          ABW  North America          Aruba  3/26/2020         19.0
# ...        ...            ...            ...        ...          ...
# 35078      NaN            NaN  International  2/28/2020        705.0
# 35079      NaN            NaN  International  2/29/2020        705.0
# 35080      NaN            NaN  International   3/1/2020        705.0
# 35081      NaN            NaN  International   3/2/2020        705.0
# 35082      NaN            NaN  International  3/10/2020        696.0
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# 0            2.0           0.0         0.0                   18.733
# 1            2.0           0.0         0.0                   37.465
# 2            8.0           0.0         0.0                  112.395
# 3            5.0           0.0         0.0                  159.227
# 4            2.0           0.0         0.0                  177.959
# ...          ...           ...         ...                      ...
# 35078        0.0           4.0         0.0                      NaN
# 35079        0.0           6.0         2.0                      NaN
# 35080        0.0           6.0         0.0                      NaN
# 35081        0.0           6.0         0.0                      NaN
# 35082       -9.0           7.0         1.0                      NaN
#
#        new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 0                     18.733  ...          7.452       35973.781
# 1                     18.733  ...          7.452       35973.781
# 2                     74.930  ...          7.452       35973.781
# 3                     46.831  ...          7.452       35973.781
# 4                     18.733  ...          7.452       35973.781
# ...                      ...  ...            ...             ...
# 35078                    NaN  ...            NaN             NaN
# 35079                    NaN  ...            NaN             NaN
# 35080                    NaN  ...            NaN             NaN
# 35081                    NaN  ...            NaN             NaN
# 35082                    NaN  ...            NaN             NaN
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                    NaN                11.62
# 1                  NaN                    NaN                11.62
# 2                  NaN                    NaN                11.62
# 3                  NaN                    NaN                11.62
# 4                  NaN                    NaN                11.62
# ...                ...                    ...                  ...
# 35078              NaN                    NaN                  NaN
# 35079              NaN                    NaN                  NaN
# 35080              NaN                    NaN                  NaN
# 35081              NaN                    NaN                  NaN
# 35082              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                     NaN
# 1                 NaN           NaN                     NaN
# 2                 NaN           NaN                     NaN
# 3                 NaN           NaN                     NaN
# 4                 NaN           NaN                     NaN
# ...               ...           ...                     ...
# 35078             NaN           NaN                     NaN
# 35079             NaN           NaN                     NaN
# 35080             NaN           NaN                     NaN
# 35081             NaN           NaN                     NaN
# 35082             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy
# 0                             NaN            76.29
# 1                             NaN            76.29
# 2                             NaN            76.29
# 3                             NaN            76.29
# 4                             NaN            76.29
# ...                           ...              ...
# 35078                         NaN              NaN
# 35079                         NaN              NaN
# 35080                         NaN              NaN
# 35081                         NaN              NaN
# 35082                         NaN              NaN
#
# [35083 rows x 36 columns]

# %%
euribor
# Out:
#          Date  Interest Rate
# 0  2020-05-01         -0.157
# 1  2020-05-02         -0.157
# 2  2020-05-03         -0.157
# 3  2020-05-04         -0.157
# 4  2020-05-05         -0.165
# ..        ...            ...
# 93 2020-08-02         -0.407
# 94 2020-08-03         -0.417
# 95 2020-08-04         -0.421
# 96 2020-08-05         -0.418
# 97 2020-08-06         -0.418
#
# [98 rows x 2 columns]

# %%
covid = covid.loc[covid['continent'] == 'Europe']

# %%
covid
# Out:
#        iso_code continent location       date  total_cases  new_cases  \
# 618         ALB    Europe  Albania   3/9/2020          2.0        2.0
# 619         ALB    Europe  Albania  3/10/2020          6.0        4.0
# 620         ALB    Europe  Albania  3/11/2020         10.0        4.0
# 621         ALB    Europe  Albania  3/12/2020         11.0        1.0
# 622         ALB    Europe  Albania  3/13/2020         23.0       12.0
# ...         ...       ...      ...        ...          ...        ...
# 34213  OWID_KOS    Europe   Kosovo   8/2/2020       8104.0        0.0
# 34214  OWID_KOS    Europe   Kosovo   8/3/2020       8799.0      695.0
# 34215  OWID_KOS    Europe   Kosovo   8/4/2020       9049.0      250.0
# 34216  OWID_KOS    Europe   Kosovo   8/5/2020       9274.0      225.0
# 34217  OWID_KOS    Europe   Kosovo   8/6/2020       9274.0        0.0
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 618             0.0         0.0                    0.695
# 619             0.0         0.0                    2.085
# 620             0.0         0.0                    3.475
# 621             1.0         1.0                    3.822
# 622             1.0         0.0                    7.992
# ...             ...         ...                      ...
# 34213         212.0         0.0                 4192.937
# 34214         249.0        37.0                 4552.524
# 34215         256.0         7.0                 4681.872
# 34216         296.0        40.0                 4798.285
# 34217         296.0         0.0                 4798.285
#
#        new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
# 618                    0.695  ...          8.643       11803.431
# 619                    1.390  ...          8.643       11803.431
# 620                    1.390  ...          8.643       11803.431
# 621                    0.347  ...          8.643       11803.431
# 622                    4.170  ...          8.643       11803.431
# ...                      ...  ...            ...             ...
# 34213                  0.000  ...            NaN        9795.834
# 34214                359.587  ...            NaN        9795.834
# 34215                129.348  ...            NaN        9795.834
# 34216                116.413  ...            NaN        9795.834
# 34217                  0.000  ...            NaN        9795.834
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 618                1.1                304.195                10.08
# 619                1.1                304.195                10.08
# 620                1.1                304.195                10.08
# 621                1.1                304.195                10.08
# 622                1.1                304.195                10.08
# ...                ...                    ...                  ...
# 34213              0.6                    NaN                  NaN
# 34214              0.6                    NaN                  NaN
# 34215              0.6                    NaN                  NaN
# 34216              0.6                    NaN                  NaN
# 34217              0.6                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 618               7.1          51.2                     NaN
# 619               7.1          51.2                     NaN
# 620               7.1          51.2                     NaN
# 621               7.1          51.2                     NaN
# 622               7.1          51.2                     NaN
# ...               ...           ...                     ...
# 34213             NaN           NaN                     NaN
# 34214             NaN           NaN                     NaN
# 34215             NaN           NaN                     NaN
# 34216             NaN           NaN                     NaN
# 34217             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy
# 618                          2.89            78.57
# 619                          2.89            78.57
# 620                          2.89            78.57
# 621                          2.89            78.57
# 622                          2.89            78.57
# ...                           ...              ...
# 34213                         NaN              NaN
# 34214                         NaN              NaN
# 34215                         NaN              NaN
# 34216                         NaN              NaN
# 34217                         NaN              NaN
#
# [9527 rows x 36 columns]

# %%
# get dates
def get_dates(dates):
    dates_array = []
    
    for i in range(len(dates)):
        date = str(dates.iloc[i])
        dates_array.append(parser.parse(date))
    return dates_array

euribor_dates = get_dates(euribor['Date'])
covid_dates = get_dates(covid['date'])

# %%
# reduce covid dataset May to Aug 2020, replace NaN
euribor['Date'] = euribor_dates
covid.iloc[:, 3] = covid_dates #?
res = covid[~(covid['date'] < '2020-05-01')]
res = res.fillna(0)

# %%
# group by countries
groups = []
countries = set(np.array(covid['location']))
for country in countries:
    grouped = res.groupby(res.location)
    group = grouped.get_group(country)
    groups.append(group)

# %%
groups
# Out:
# [       iso_code continent location       date  total_cases  new_cases  \
#  34120  OWID_KOS    Europe   Kosovo 2020-05-01        820.0       12.0
#  34121  OWID_KOS    Europe   Kosovo 2020-05-02        829.0        9.0
#  34122  OWID_KOS    Europe   Kosovo 2020-05-03        840.0       11.0
#  34123  OWID_KOS    Europe   Kosovo 2020-05-04        851.0       11.0
#  34124  OWID_KOS    Europe   Kosovo 2020-05-05        855.0        4.0
#  ...         ...       ...      ...        ...          ...        ...
#  34213  OWID_KOS    Europe   Kosovo 2020-08-02       8104.0        0.0
#  34214  OWID_KOS    Europe   Kosovo 2020-08-03       8799.0      695.0
#  34215  OWID_KOS    Europe   Kosovo 2020-08-04       9049.0      250.0
#  34216  OWID_KOS    Europe   Kosovo 2020-08-05       9274.0      225.0
#  34217  OWID_KOS    Europe   Kosovo 2020-08-06       9274.0        0.0
#
#         total_deaths  new_deaths  total_cases_per_million  \
#  34120          24.0         3.0                  424.261
#  34121          24.0         0.0                  428.917
#  34122          25.0         1.0                  434.608
#  34123          25.0         0.0                  440.300
#  34124          26.0         1.0                  442.369
#  ...             ...         ...                      ...
#  34213         212.0         0.0                 4192.937
#  34214         249.0        37.0                 4552.524
#  34215         256.0         7.0                 4681.872
#  34216         296.0        40.0                 4798.285
#  34217         296.0         0.0                 4798.285
#
#         new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
#  34120                  6.209  ...            0.0        9795.834
#  34121                  4.657  ...            0.0        9795.834
#  34122                  5.691  ...            0.0        9795.834
#  34123                  5.691  ...            0.0        9795.834
#  34124                  2.070  ...            0.0        9795.834
#  ...                      ...  ...            ...             ...
#  34213                  0.000  ...            0.0        9795.834
#  34214                359.587  ...            0.0        9795.834
#  34215                129.348  ...            0.0        9795.834
#  34216                116.413  ...            0.0        9795.834
#  34217                  0.000  ...            0.0        9795.834
#
#         extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
#  34120              0.6                    0.0                  0.0
#  34121              0.6                    0.0                  0.0
#  34122              0.6                    0.0                  0.0
#  34123              0.6                    0.0                  0.0
#  34124              0.6                    0.0                  0.0
#  ...                ...                    ...                  ...
#  34213              0.6                    0.0                  0.0
#  34214              0.6                    0.0                  0.0
#  34215              0.6                    0.0                  0.0
#  34216              0.6                    0.0                  0.0
#  34217              0.6                    0.0                  0.0
#
#         female_smokers  male_smokers  handwashing_facilities  \
#
#  13300         208.0         2.0                  447.278
#  13301         209.0         1.0                  454.473
#  13302         209.0         0.0                  465.794
#  13303         210.0         1.0                  477.115
#
#         new_cases_per_million  ...  aged_70_older  gdp_per_capita  \
#  13206                  1.439  ...         14.524       24574.382
#  13207                  0.000  ...         14.524       24574.382
#  13208                  2.782  ...         14.524       24574.382
#  13209                  0.576  ...         14.524       24574.382
#  13210                  0.576  ...         14.524       24574.382
#  ...                      ...  ...            ...             ...
#  13299                 10.554  ...         14.524       24574.382
#  13300                  7.196  ...         14.524       24574.382
#  13301                  7.196  ...         14.524       24574.382
#  13302                 11.321  ...         14.524       24574.382
#  13303                 11.321  ...         14.524       24574.382
#
#         extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
#  13206              1.5                175.695                 4.55
#  13207              1.5                175.695                 4.55
#  13208              1.5                175.695                 4.55
#  13209              1.5                175.695                 4.55
#  13210              1.5                175.695                 4.55
#  ...                ...                    ...                  ...
#  13299              1.5                175.695                 4.55
#  13300              1.5                175.695                 4.55
#  13301              1.5                175.695                 4.55
#  13302              1.5                175.695                 4.55
#  13303              1.5                175.695                 4.55
#
#         female_smokers  male_smokers  handwashing_facilities  \
#  13206            35.3          52.0                     0.0
#  13207            35.3          52.0                     0.0
#  13208            35.3          52.0                     0.0
#  13209            35.3          52.0                     0.0
#  13210            35.3          52.0                     0.0
#  ...               ...           ...                     ...
#  13299            35.3          52.0                     0.0
#  13300            35.3          52.0                     0.0
#  13301            35.3          52.0                     0.0
#  13302            35.3          52.0                     0.0
#  13303            35.3          52.0                     0.0
#
#         hospital_beds_per_thousand  life_expectancy
#  13206                        4.21            82.24
#  13207                        4.21            82.24
#  13208                        4.21            82.24
#  13209                        4.21            82.24
#  13210                        4.21            82.24
#  ...                           ...              ...
#  13299                        4.21            82.24
#  13300                        4.21            82.24
#  13301                        4.21            82.24
#  13302                        4.21            82.24
#  13303                        4.21            82.24
#
#  [98 rows x 36 columns]]

# %%
# fixes err: operands could not be broadcast together with shapes (98,) (97,) 
for i in range(len(groups)):
    if (len(groups[i]) == 97):
        groups[i].loc[len(groups[i])] = 0

# %%
# total cases added
total_cases_per_million = np.zeros(98)
for i in range(len(groups)):
    df = groups[i]
    total_cases_per_million = np.add(total_cases_per_million, np.array(df['total_cases_per_million']))

# %%
dates = euribor_dates
euribor_rates = list(euribor.iloc[:,1])

# %%
# Show plot
fig, ax1 = plt.subplots()

fig.suptitle('Correlation between Number of COVID_19 cases and Interest Rate', fontsize=20)

color = 'tab:red'
# ax1.set_xlabel('Dates')
ax1.set_ylabel('Interest Rate', color=color, fontsize=18)
ax1.plot(dates, euribor_rates, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('# of cases', color=color, fontsize=18)
ax2.plot(dates, total_cases_per_million, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# fig.tight_layout()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %%
# Linear Regression Model_1, coleratin between total cases and euribor rates
model = LinearRegression()
regressor = model.fit(total_cases_per_million.reshape((-1,1)), euribor_rates) #reshape used because expected 2D got 1D

# %%
regressor.score(total_cases_per_million.reshape((-1,1)), euribor_rates) # accuracy for dataset
# Out:
# 0.9445968634863596

# %%
linregressResult = stats.linregress(total_cases_per_million, euribor_rates) # pvalue < 0.5
linregressResult
# Out:
# LinregressResult(slope=-3.903807031287853e-06, intercept=0.4068601109857126, rvalue=-0.9719037315940088, pvalue=4.087328926588472e-62, stderr=9.649318726687244e-08)

# %%
period = np.linspace(0, 98, 98) # 0-98th day (3 months period)
period
# Out:
# array([ 0.        ,  1.01030928,  2.02061856,  3.03092784,  4.04123711,
#         5.05154639,  6.06185567,  7.07216495,  8.08247423,  9.09278351,
#        10.10309278, 11.11340206, 12.12371134, 13.13402062, 14.1443299 ,
#        15.15463918, 16.16494845, 17.17525773, 18.18556701, 19.19587629,
#        20.20618557, 21.21649485, 22.22680412, 23.2371134 , 24.24742268,
#        25.25773196, 26.26804124, 27.27835052, 28.28865979, 29.29896907,
#        30.30927835, 31.31958763, 32.32989691, 33.34020619, 34.35051546,
#        35.36082474, 36.37113402, 37.3814433 , 38.39175258, 39.40206186,
#        40.41237113, 41.42268041, 42.43298969, 43.44329897, 44.45360825,
#        45.46391753, 46.4742268 , 47.48453608, 48.49484536, 49.50515464,
#        50.51546392, 51.5257732 , 52.53608247, 53.54639175, 54.55670103,
#        55.56701031, 56.57731959, 57.58762887, 58.59793814, 59.60824742,
#        60.6185567 , 61.62886598, 62.63917526, 63.64948454, 64.65979381,
#        65.67010309, 66.68041237, 67.69072165, 68.70103093, 69.71134021,
#        70.72164948, 71.73195876, 72.74226804, 73.75257732, 74.7628866 ,
#        75.77319588, 76.78350515, 77.79381443, 78.80412371, 79.81443299,
#        80.82474227, 81.83505155, 82.84536082, 83.8556701 , 84.86597938,
#        85.87628866, 86.88659794, 87.89690722, 88.90721649, 89.91752577,
#        90.92783505, 91.93814433, 92.94845361, 93.95876289, 94.96907216,
#        95.97938144, 96.98969072, 98.        ])

# %%
# Linear Regression Model_2, colleration between total covid cases and time
model2 = LinearRegression()
regressor2 = model2.fit(period.reshape((-1,1)), total_cases_per_million)
predict = np.linspace(98,245,147)

# %%
predicted = model2.predict(predict.reshape((-1,1)))
predicted
# Out:
# array([208227.44017934, 209053.17141835, 209878.90265736, 210704.63389637,
#        211530.36513538, 212356.09637438, 213181.82761339, 214007.5588524 ,
#        214833.29009141, 215659.02133042, 216484.75256943, 217310.48380843,
#        218136.21504744, 218961.94628645, 219787.67752546, 220613.40876447,
#        221439.14000347, 222264.87124248, 223090.60248149, 223916.3337205 ,
#        224742.06495951, 225567.79619851, 226393.52743752, 227219.25867653,
#        228044.98991554, 228870.72115455, 229696.45239355, 230522.18363256,
#        231347.91487157, 232173.64611058, 232999.37734959, 233825.10858859,
#        234650.8398276 , 235476.57106661, 236302.30230562, 237128.03354463,
#        237953.76478363, 238779.49602264, 239605.22726165, 240430.95850066,
#        241256.68973967, 242082.42097867, 242908.15221768, 243733.88345669,
#        244559.6146957 , 245385.34593471, 246211.07717372, 247036.80841272,
#        247862.53965173, 248688.27089074, 249514.00212975, 250339.73336876,
#        -0.69613422, -0.69935772, -0.70258121, -0.70580471, -0.7090282 ,
#        -0.7122517 , -0.71547519, -0.71869869, -0.72192218, -0.72514568,
#        -0.72836918, -0.73159267, -0.73481617, -0.73803966, -0.74126316,
#        -0.74448665, -0.74771015, -0.75093364, -0.75415714, -0.75738063,
#        -0.76060413, -0.76382763, -0.76705112, -0.77027462, -0.77349811,
#        -0.77672161, -0.7799451 , -0.7831686 , -0.78639209, -0.78961559,
#        -0.79283908, -0.79606258, -0.79928607, -0.80250957, -0.80573307,
#        -0.80895656, -0.81218006, -0.81540355, -0.81862705, -0.82185054,
#        -0.82507404, -0.82829753, -0.83152103, -0.83474452, -0.83796802,
#        -0.84119152, -0.84441501, -0.84763851, -0.850862  , -0.8540855 ,
#        -0.85730899, -0.86053249, -0.86375598, -0.86697948, -0.87020297,
#        -0.87342647, -0.87664996])

# %%
from datetime import date, timedelta
sdate = date(2020, 8, 7)   # start date
edate = date(2020, 12, 31)   # end date

delta = edate - sdate       # as timedelta
days = []
for i in range(delta.days + 1):
    day = sdate + timedelta(days=i)
    days.append(day)

# %%
# Show plot for predicted covid_19 cases
fig, ax1 = plt.subplots()
fig.suptitle('Predicted values for # of Covid_19 cases', fontsize=20)

plt.plot(dates, total_cases_per_million, label='Real values')
plt.plot(days, predicted, color = 'red', label='Predicted values')

fig.set_size_inches(18.5, 10.5)
plt.legend()
plt.show()

# %%
# Show plot for predicted interest rates
fig, ax1 = plt.subplots()
fig.suptitle('Predicted values for interest rates', fontsize=20)

plt.plot(dates, euribor_rates, label='Real values')
plt.plot(days, interest_rates, color = 'red', label='Predicted values')

fig.set_size_inches(18.5, 10.5)
plt.legend()
plt.show()

# %%
# ARIMA Model
model = ARIMA(total_cases_per_million, order=(5,1,0))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()

plt.show()
residuals.plot(kind='kde')
plt.show()
print(residuals.describe())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                    D.y   No. Observations:                   97
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -765.446
# Method:                       css-mle   S.D. of innovations            646.156
# Date:                Tue, 13 Oct 2020   AIC                           1544.891
# Time:                        19:37:22   BIC                           1562.914
# Sample:                             1   HQIC                          1552.179
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        819.7811    112.807      7.267      0.000     598.684    1040.878
# ar.L1.D.y      0.2829      0.217      1.303      0.196      -0.143       0.708
# ar.L2.D.y     -0.1397      0.225     -0.622      0.535      -0.580       0.300
# ar.L3.D.y      0.0828      0.220      0.377      0.707      -0.348       0.514
# ar.L4.D.y      0.0805      0.218      0.369      0.713      -0.347       0.508
# ar.L5.D.y      0.1033      0.200      0.517      0.607      -0.289       0.495
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3279           -0.0000j            1.3279           -0.0000
# AR.2            0.3517           -1.4028j            1.4463           -0.2109
# AR.3            0.3517           +1.4028j            1.4463            0.2109
# AR.4           -1.4055           -1.2289j            1.8670           -0.3856
# AR.5           -1.4055           +1.2289j            1.8670            0.3856
# -----------------------------------------------------------------------------
#                  0
# count    97.000000
# mean     -0.874846
# std     649.593006
# min   -5539.069968
# 25%    -102.799858
# 50%      -9.349564
# 75%     151.428814
# max    1750.656999

# %%
from sklearn.metrics import mean_squared_error
X = total_cases_per_million
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
fig, ax1 = plt.subplots()
fig.suptitle('Predicted values for total cases per million', fontsize=20)

plt.plot(test, label='Real values')
plt.plot(predictions, color = 'red', label='Predicted values')

fig.set_size_inches(18.5, 10.5)
plt.legend()
plt.show()
# Out:
# predicted=177523.865011, expected=177523.077000
# predicted=178306.022983, expected=178319.389000
# predicted=179104.683148, expected=179161.487000
# predicted=179927.650312, expected=180061.140000
# predicted=180918.837324, expected=180922.356000
# predicted=181724.017447, expected=181918.091000
# predicted=182781.464426, expected=182944.844000
# predicted=183795.174299, expected=183983.731000
# predicted=184887.173017, expected=185147.190000
# predicted=186072.434187, expected=185990.806000
# predicted=186786.379232, expected=187138.278000
# predicted=188136.163300, expected=188050.506000
# predicted=188828.827074, expected=188976.023000
# predicted=189951.685879, expected=190066.021000
# predicted=190919.068643, expected=191245.124000
# predicted=192263.849645, expected=192278.140000
# predicted=193199.273501, expected=193325.436000
# predicted=194249.776911, expected=194423.049000
# predicted=195364.493096, expected=195462.000000
# predicted=196436.515913, expected=196936.863000
# predicted=198099.507494, expected=198647.103000
# predicted=199909.635263, expected=200210.076000
# predicted=201532.445709, expected=201367.704000
# predicted=202403.232964, expected=202324.367000
# predicted=203320.712112, expected=204624.045000
# predicted=206435.791825, expected=205903.684000
# predicted=207053.353735, expected=207484.607000
# predicted=209037.422602, expected=208966.081000
# predicted=210016.611130, expected=210243.757000
# predicted=211802.703969, expected=211285.719000
# predicted=212387.880935, expected=212626.217000
# predicted=213880.519900, expected=214149.897000
# predicted=215447.252988, expected=215532.251000
# predicted=216807.413313, expected=210982.067000
# Test MSE: 1110592.115

# %%
X = euribor_rates
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)

# plot
fig, ax1 = plt.subplots()
fig.suptitle('Predicted values for euribor rates', fontsize=20)

plt.plot(test, label='Real values')
plt.plot(predictions, color = 'red', label='Predicted values')

fig.set_size_inches(18.5, 10.5)
plt.legend()
plt.show()
# Out:
# predicted=-0.315222, expected=-0.314000
# predicted=-0.313040, expected=-0.314000
# predicted=-0.319315, expected=-0.308000
# predicted=-0.312625, expected=-0.313000
# predicted=-0.315431, expected=-0.322000
# predicted=-0.322301, expected=-0.328000
# predicted=-0.328378, expected=-0.330000
# predicted=-0.332856, expected=-0.330000
# predicted=-0.333611, expected=-0.330000
# predicted=-0.333270, expected=-0.332000
# predicted=-0.334592, expected=-0.330000
# predicted=-0.332749, expected=-0.333000
# predicted=-0.335775, expected=-0.352000
# predicted=-0.351923, expected=-0.351000
# predicted=-0.351090, expected=-0.351000
# predicted=-0.355414, expected=-0.351000
# predicted=-0.355356, expected=-0.348000
# predicted=-0.350644, expected=-0.353000
# predicted=-0.355836, expected=-0.355000
# predicted=-0.356820, expected=-0.373000
# predicted=-0.373281, expected=-0.373000
# predicted=-0.373872, expected=-0.373000
# predicted=-0.818265, expected=-0.818627
# predicted=-0.821490, expected=-0.821851
# predicted=-0.824715, expected=-0.825074
# predicted=-0.827940, expected=-0.828298
# predicted=-0.831165, expected=-0.831521
# predicted=-0.834390, expected=-0.834745
# predicted=-0.837615, expected=-0.837968
# predicted=-0.840840, expected=-0.841192
# predicted=-0.844066, expected=-0.844415
# predicted=-0.847291, expected=-0.847639
# predicted=-0.850516, expected=-0.850862
# predicted=-0.853741, expected=-0.854085
# predicted=-0.856965, expected=-0.857309
# predicted=-0.860190, expected=-0.860532
# predicted=-0.863415, expected=-0.863756
# predicted=-0.866640, expected=-0.866979
# predicted=-0.869865, expected=-0.870203
# predicted=-0.873090, expected=-0.873426
# predicted=-0.876315, expected=-0.876650
# Test MSE: 0.000

# %%
# Part2 Korelacii pomegu starost i mortality (nema podobar dataset so komorbiditeti)
# data set MK zaboleni/umreni vrz osnova na toa kakvi ke bidat kamatnite stapki 
patientInfo = pd.read_csv("C:/Users/MartinV/Downloads/PatientInfo.csv")

# %%
patientInfo
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# 3     1000000004         7.0    male      1991.0  20s   Korea
# 4     1000000005         9.0  female      1992.0  20s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 2238  6100000085         NaN    male      1990.0  30s   Korea
# 2239  7000000001       139.0    male      1998.0  20s   Korea
# 2240  7000000002       222.0  female      1998.0  20s   Korea
# 2241  7000000003      4345.0  female      1972.0  40s   Korea
# 2242  7000000004      5534.0    male      1974.0  40s   Korea
#
#               province         city disease        infection_case  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow
# 1                Seoul  Jungnang-gu     NaN       overseas inflow
# 2                Seoul    Jongno-gu     NaN  contact with patient
# 3                Seoul      Mapo-gu     NaN       overseas inflow
# 4                Seoul  Seongbuk-gu     NaN  contact with patient
# ...                ...          ...     ...                   ...
# 2238  Gyeongsangnam-do  Changwon-si     NaN                   NaN
# 2239           Jeju-do      Jeju-do     NaN                   etc
# 2240           Jeju-do      Jeju-do     NaN                   etc
# 2241           Jeju-do          etc     NaN                   etc
# 2242           Jeju-do      Jeju-do     NaN                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 0                 1.0           NaN            75.0         2020-01-22
# 1                 1.0           NaN            31.0                NaN
# 2                 2.0  2.002000e+09            17.0                NaN
# 3                 1.0           NaN             9.0         2020-01-26
# 4                 2.0  1.000000e+09             2.0                NaN
# ...               ...           ...             ...                ...
# 2238              NaN           NaN             NaN                NaN
# 2239              NaN           NaN            87.0                NaN
# 2240              NaN           NaN            84.0                NaN
# 2241              NaN           NaN            21.0                NaN
# 2242              NaN           NaN            74.0                NaN
#
#      confirmed_date released_date deceased_date     state
# 0        2020-01-23    2020-02-05           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# 2        2020-01-30    2020-02-19           NaN  released
# 3        2020-01-30    2020-02-15           NaN  released
# 4        2020-01-31    2020-02-24           NaN  released
# ...             ...           ...           ...       ...
# 2238     2020-03-16           NaN           NaN       NaN
# 2239     2020-02-20           NaN           NaN  isolated
# 2240     2020-02-22    2020-03-07           NaN  released
# 2241     2020-03-02    2020-03-15           NaN  released
# 2242     2020-03-04           NaN           NaN  isolated
#
# [2243 rows x 18 columns]

# %%
patientInfo = patientInfo[patientInfo['age'].notna()]
patientInfo
# Out:
#       patient_id  global_num     sex  birth_year  age country  \
# 0     1000000001         2.0    male      1964.0  50s   Korea
# 1     1000000002         5.0    male      1987.0  30s   Korea
# 2     1000000003         6.0    male      1964.0  50s   Korea
# 3     1000000004         7.0    male      1991.0  20s   Korea
# 4     1000000005         9.0  female      1992.0  20s   Korea
# ...          ...         ...     ...         ...  ...     ...
# 2238  6100000085         NaN    male      1990.0  30s   Korea
# 2239  7000000001       139.0    male      1998.0  20s   Korea
# 2240  7000000002       222.0  female      1998.0  20s   Korea
# 2241  7000000003      4345.0  female      1972.0  40s   Korea
# 2242  7000000004      5534.0    male      1974.0  40s   Korea
#
#               province         city disease        infection_case  \
# 0                Seoul   Gangseo-gu     NaN       overseas inflow
# 1                Seoul  Jungnang-gu     NaN       overseas inflow
# 2                Seoul    Jongno-gu     NaN  contact with patient
# 3                Seoul      Mapo-gu     NaN       overseas inflow
# 4                Seoul  Seongbuk-gu     NaN  contact with patient
# ...                ...          ...     ...                   ...
# 2238  Gyeongsangnam-do  Changwon-si     NaN                   NaN
# 2239           Jeju-do      Jeju-do     NaN                   etc
# 2240           Jeju-do      Jeju-do     NaN                   etc
# 2241           Jeju-do          etc     NaN                   etc
# 2242           Jeju-do      Jeju-do     NaN                   etc
#
#       infection_order   infected_by  contact_number symptom_onset_date  \
# 0                 1.0           NaN            75.0         2020-01-22
# 1                 1.0           NaN            31.0                NaN
# 2                 2.0  2.002000e+09            17.0                NaN
# 3                 1.0           NaN             9.0         2020-01-26
# 4                 2.0  1.000000e+09             2.0                NaN
# ...               ...           ...             ...                ...
# 2238              NaN           NaN             NaN                NaN
# 2239              NaN           NaN            87.0                NaN
# 2240              NaN           NaN            84.0                NaN
# 2241              NaN           NaN            21.0                NaN
# 2242              NaN           NaN            74.0                NaN
#
#      confirmed_date released_date deceased_date     state
# 0        2020-01-23    2020-02-05           NaN  released
# 1        2020-01-30    2020-03-02           NaN  released
# 2        2020-01-30    2020-02-19           NaN  released
# 3        2020-01-30    2020-02-15           NaN  released
# 4        2020-01-31    2020-02-24           NaN  released
# ...             ...           ...           ...       ...
# 2238     2020-03-16           NaN           NaN       NaN
# 2239     2020-02-20           NaN           NaN  isolated
# 2240     2020-02-22    2020-03-07           NaN  released
# 2241     2020-03-02    2020-03-15           NaN  released
# 2242     2020-03-04           NaN           NaN  isolated
#
# [1985 rows x 18 columns]

# %%
age = np.array(patientInfo['age'])
age_intervals = set(np.array(patientInfo['age']))
age_interval = np.array(list(age_intervals))
age_cohorts = np.zeros((len(age), len(age_intervals)))

# %%
def convertAgeToNumber(arr):
    switcher = {
        "0s": 1,
        "10s": 1,
        "20s": 2,
        "30s": 3,
        "40s": 4,
        "50s": 5,
        "60s": 6,
        "70s": 7,
        "80s": 8,
        "90s": 9,
        "100s": 9
    }
    for i in range(len(arr)):
        arr[i] = switcher[arr[i]]

    return arr

# %%
convertedAges = convertAgeToNumber(age)
convertedAges
# Out:
# array([5, 3, 5, ..., 2, 4, 4], dtype=object)

# %%
# Binarize Patient Info State
def patientInfoStatesToInt(patientInfoStates):
    for i in range(len(patientInfoStates)):
        if patientInfoStates[i] == 'deceased':
            patientInfoStates[i] = 1
        else:
            patientInfoStates[i] = 0

    return patientInfoStates.astype('int')

patientInfoStates = patientInfoStatesToInt(np.array(patientInfo['state']))
patientInfoStates
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# Logistic Regression
clf = LogisticRegression(random_state=0).fit(convertedAges.reshape((-1,1)), patientInfoStates.reshape((-1,1)))
#clf.predict(X[:2, :])
#clf.predict_proba(X[:2, :])
clf.score(convertedAges.reshape((-1,1)), patientInfoStates)
# Out:
# 0.9843828715365239

# %%
# Logistic Regression with train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(convertedAges, patientInfoStates, test_size=0.33, random_state=42)

clf = LogisticRegression(random_state=0).fit(X_train.reshape((-1,1)), y_train.reshape((-1,1)))
clf.score(X_test.reshape((-1,1)), y_test)
# Out:
# 0.9908536585365854

# %%
# !! ValueError: Number of labels=656 does not match number of samples=1329
# Decision Tree Classifier
tree_model = tree.DecisionTreeClassifier()
tree_model = tree_model.fit(X_train.reshape((-1,1)), y_train)
y_pred = tree_model.predict(X_test.reshape((-1,1)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-e963fea5f412> in <module>
#       2 from sklearn import tree
#       3 tree_model = tree.DecisionTreeClassifier()
# ----> 4 tree_model = tree_model.fit(X_train.reshape((-1,1)), y_test)
#       5 y_pred = tree_model.predict(X_test.reshape((-1,1)))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     248         if len(y) != n_samples:
#     249             raise ValueError("Number of labels=%d does not match "
# --> 250                              "number of samples=%d" % (len(y), n_samples))
#     251         if not 0 <= self.min_weight_fraction_leaf <= 0.5:
#     252             raise ValueError("min_weight_fraction_leaf must in [0, 0.5]")
#
# ValueError: Number of labels=656 does not match number of samples=1329

# %%
# accuracy_score
from sklearn.metrics import accuracy_score
accuracy_dt = accuracy_score(y_test, y_pred)
accuracy_dt

# %%
# roc_auc_score
from sklearn.metrics import roc_auc_score
roc_auc = roc_auc_score(y_test, y_pred)
roc_auc   #BAD ROC CURVE -> UNBALANCED DATA -> BIASED

# %%
# ?
X_train_df = pd.DataFrame({'age': X_train})
y_train_df = pd.DataFrame({'state': y_train})
X_new = pd.concat([X_train_df, y_train_df], axis=1)
X_new
# Out:
#      age  state
# 0      4      0
# 1      2      0
# 2      5      0
# 3      5      0
# 4      7      1
# ...   ..    ...
# 1324   8      0
# 1325   4      0
# 1326   4      0
# 1327   9      0
# 1328   5      0
#
# [1329 rows x 2 columns]

# %%
#OVERSAMLPING MINORITY -> BALANCING DATA -> FIXING ROC 
# separate minority and majority classes
not_deceased = X_new[X_new.state==0]
deceased = X_new[X_new.state==1]

# upsample minority
deceased_upsampled = resample(deceased,
                          replace=True, # sample with replacement
                          n_samples=len(not_deceased), # match number in majority class
                          random_state=27) # reproducible results

# combine majority and upsampled minority
upsampled = pd.concat([not_deceased, deceased_upsampled])

# check new class counts
upsampled.state.value_counts()
# Out:
# 1    1304
# 0    1304
# Name: state, dtype: int64

# %%
len(y_train)
# Out:
# 1329

# %%
# Decision Tree Classifier
y_train_dt = upsampled.state
X_train_dt = upsampled.drop('state', axis=1)

tree_model_2 = tree.DecisionTreeClassifier()
upsampled = tree_model_2.fit(np.array(X_train_dt).reshape((-1,1)), np.array(y_train_dt))

upsampled_pred = upsampled.predict(X_test.reshape((-1,1)))
as_dt = accuracy_score(y_test, upsampled_pred)
roc_auc = roc_auc_score(y_test, upsampled_pred)
print("Accuracy:", as_dt)
print("Error: ", 1-as_dt)
print("ROC: ", roc_auc)
# Out:
# 0.7112820512820512

# %%
# Support Vector Machine
clf_svm = svm.SVC()
clf_svm.fit(np.array(X_train_dt).reshape((-1,1)), np.array(y_train_dt))
clf_svm_pred = clf_svm.predict(X_test.reshape((-1,1)))
as_svm = accuracy_score(y_test, clf_svm_pred)
roc_auc_svm = roc_auc_score(y_test, clf_svm_pred)
print("Accuracy:", as_svm)
print("Error: ", 1-as_svm)
print("ROC: ", roc_auc_svm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-4b58a3b98d06> in <module>
#       1 # Support Vector Machine
#       2 clf_svm = svm.SVC()
# ----> 3 clf_svm.fit(np.array(X_train_dt).reshape((-1,1)), np.array(y_train_dt))
#       4 clf_svm_pred = clf_svm.predict(X_test.reshape((-1,1)))
#       5 as_svm = accuracy_score(y_test, clf_svm_pred)
#
# NameError: name 'X_train_dt' is not defined

# %%
precision_recall_fscore_support(y_test, clf_svm_pred, average='weighted') # ?

# %%
# MLPClassifier ? TODO explain
clf_mlp = MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
clf_mlp.fit(np.array(X_train_up).reshape((-1,1)), np.array(y_train_up))
clf_mlp_pred = clf_mlp.predict(X_test.reshape((-1,1)))
as_mlp = accuracy_score(y_test, clf_mlp_pred)
roc_auc_mlp = roc_auc_score(y_test, clf_mlp_pred)
print("Accuracy:", as_mlp)
print("Error: ", 1-as_mlp)
print("ROC: ", roc_auc_mlp)

# %%
precision_recall_fscore_support(y_test, clf_mlp_pred, average='weighted')

# %%
# RandomForestClassifier ? 
clf_rf = RandomForestClassifier(max_depth=2, random_state=0)
clf_rf.fit(np.array(X_train_up).reshape((-1,1)), y_train_up)
y_pred_rf = clf_rf.predict(X_test.reshape((-1,1)))
as_rf = accuracy_score(y_test, y_pred_rf)
roc_auc_rf = roc_auc_score(y_test, y_pred_rf)
print("Accuracy:", as_rf)
print("Error: ", 1-as_rf)
print("ROC: ", roc_auc_rf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a53f545b78a4> in <module>
#       1 # RandomForestClassifier ?
# ----> 2 clf_rf = RandomForestClassifier(max_depth=2, random_state=0)
#       3 clf_rf.fit(np.array(X_train_up).reshape((-1,1)), y_train_up)
#       4 y_pred_rf = clf_rf.predict(X_test.reshape((-1,1)))
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
precision_recall_fscore_support(y_test, y_pred_rf, average='weighted')

# %%
# KFold ?
kf = KFold(n_splits=3)
kf.get_n_splits(X)

print(kf)

for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %%
def get_score(model, X_train, X_test, y_train, y_test):
    model.fit(X_train, y_train)
    return model.score(X_test, y_test)

# %%
folds = StratifiedKFold(n_splits = 3)

# %%
scores_dt = [] 
scores_svm = []
scores_rf = []

for train_index, test_index in folds.split(np.array(X).reshape((-1,1)), y):
    X_train, X_test, y_train, y_test = X[train_index], X[test_index], \
                                       y[train_index], y[test_index]
    scores_dt.append(get_score(tree.DecisionTreeClassifier(), X_train.reshape((-1,1)), X_test.reshape((-1,1)), y_train, y_test))  
    scores_svm.append(get_score(svm.SVC(gamma='auto'), X_train.reshape((-1,1)), X_test.reshape((-1,1)), y_train, y_test))
    scores_rf.append(get_score(RandomForestClassifier(n_estimators=40), X_train.reshape((-1,1)), X_test.reshape((-1,1)), y_train, y_test))

# %%
print("DecisionTreeScore:", scores_dt)
print("SupportVectorMachineScore: ", scores_svm)
print("RandomForestScore: ", scores_rf)

# %%
#Phase 3 TODO ?

# %%
sl = pd.read_csv("C:/Users/MartinV/Downloads/Covid19/Covid19/Datasets/Slovenia_Interest_Rates.csv")
sl
# Out:
#        date    s1
# 0  31-01-20  0.09
# 1  29-02-20  0.04
# 2  31-03-20  0.02
# 3  30-04-20  0.27
# 4  31-05-20  0.74
# 5  30-06-20  0.42
# 6  31-07-20  0.09
# 7  31-08-20 -0.10
# 8  30-09-20 -0.08

# %%
#TODO fix err
#aproximate interest rates variation per day for each month
modifiedDates = []
aproximateRatesPerDay = [] 
for i in range(len(sl['s1'])):
    if(i is len(sl['s1'])):
        break

    numberOfDaysInMonth = sl['date'][i][:2]
        
    dailyRatesForMonth = np.linspace(sl['s1'][i], sl['s1'][i+1], numberOfDaysInMonth)
    aproximateRatesPerDay.extend(dailyRatesForMonth)
    
    for j in range(len(dailyRatesForMonth)):
        modifiedDate = str(j+1) + sl['date'][i][2:]
#         print(modifiedDate, dailyRatesForMonth[j])
        modifiedDates.append(modifiedDate)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-c87a851c88be> in <module>
#       7     numberOfDaysInMonth = sl['date'][i][:2]
#       8
# ----> 9     dailyRatesForMonth = np.linspace(sl['s1'][i], sl['s1'][i+1], numberOfDaysInMonth)
#      10     aproximateRatesPerDay.extend(dailyRatesForMonth)
#      11
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
#    4732             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 9

# %%
dataset = {
    'date': modifiedDates,
    'ratePerDay': aproximateRatesPerDay
}
df = pd.DataFrame(dataset)
# df.to_csv("slovenia_interest_rates_per_day.csv")
df
# Out:
#          date  ratePerDay
# 0     1-01-20    0.090000
# 1     2-01-20    0.088333
# 2     3-01-20    0.086667
# 3     4-01-20    0.085000
# 4     5-01-20    0.083333
# ..        ...         ...
# 239  27-08-20   -0.082667
# 240  28-08-20   -0.082000
# 241  29-08-20   -0.081333
# 242  30-08-20   -0.080667
# 243  31-08-20   -0.080000
#
# [244 rows x 2 columns]
